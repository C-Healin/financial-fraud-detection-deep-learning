# %% [markdown]
# # Financial Fraud Detection — End-to-End Demo
# This clean notebook calls the reusable project package rather than duplicating training code. The included data is synthetic.

# %%
from pathlib import Path
import json
import pandas as pd
from fraud_detection.data import load_dataset, split_dataset

# %%
DATA_PATH = Path('../data/sample/fraud_sample.csv')
df = load_dataset(DATA_PATH)
df.head()

# %%
df['is_fraud'].value_counts(normalize=True).rename('share')

# %% [markdown]
# ## Reproduce all models
# Run the next cell from the repository root when you want to regenerate artifacts and plots.

# %%
# From the repository root:
# !python scripts/train_all.py

# %% [markdown]
# ## Inspect generated metrics

# %%
metrics = json.loads(Path('../reports/model_metrics.json').read_text())
pd.DataFrame(metrics).T[['roc_auc', 'pr_auc', 'precision', 'recall', 'f1', 'threshold']]

# %% [markdown]
# ## Local inference

# %%
from fraud_detection.inference import FraudPredictor
predictor = FraudPredictor('../artifacts/models')
sample = df.iloc[0].to_dict()
predictor.predict_one(sample)
